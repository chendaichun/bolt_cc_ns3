# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42

# Ensure bokeh is installed
# %pip install bokeh

import matplotlib.pyplot as plt
from bokeh.plotting import output_notebook, figure, show
from matplotlib.ticker import LogLocator
import numpy as np

START_TIME = 1.0 # in seconds
BW = 100 # in Gbps
PORT_NO_START = 1000
SAVE_FIG = True
FIG_SIZE = (5,4)
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: bokeh in /home/dyl/miniconda3/lib/python3.12/site-packages (3.7.2)
# Requirement already satisfied: Jinja2>=2.9 in /home/dyl/miniconda3/lib/python3.12/site-packages (from bokeh) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in /home/dyl/miniconda3/lib/python3.12/site-packages (from bokeh) (1.3.0)
# Requirement already satisfied: narwhals>=1.13 in /home/dyl/miniconda3/lib/python3.12/site-packages (from bokeh) (1.37.1)
# Requirement already satisfied: numpy>=1.16 in /home/dyl/miniconda3/lib/python3.12/site-packages (from bokeh) (2.0.1)
# Requirement already satisfied: packaging>=16.8 in /home/dyl/miniconda3/lib/python3.12/site-packages (from bokeh) (23.2)
# Requirement already satisfied: pandas>=1.2 in /home/dyl/miniconda3/lib/python3.12/site-packages (from bokeh) (2.2.3)
# Requirement already satisfied: pillow>=7.1.0 in /home/dyl/miniconda3/lib/python3.12/site-packages (from bokeh) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /home/dyl/miniconda3/lib/python3.12/site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /home/dyl/miniconda3/lib/python3.12/site-packages (from bokeh) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/dyl/miniconda3/lib/python3.12/site-packages (from bokeh) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/dyl/miniconda3/lib/python3.12/site-packages (from Jinja2>=2.9->bokeh) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/dyl/miniconda3/lib/python3.12/site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/dyl/miniconda3/lib/python3.12/site-packages (from pandas>=1.2->bokeh) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/dyl/miniconda3/lib/python3.12/site-packages (from pandas>=1.2->bokeh) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/dyl/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#@title
def read_flow_stats(flow_stats_filename):

  flow_stats = {}
  with open(flow_stats_filename, 'r') as f:
    for line in f:
      flow_stat_log = line.split()

      time = (float(flow_stat_log[0])*1e-9 - START_TIME) * 1e3 # in miliseconds
      sender = flow_stat_log[1]
      cwnd = float(flow_stat_log[4]) * 1e-3 # in KB
      rtt = float(flow_stat_log[5]) * 1e-3 # in usec

      if (rtt != 0):
        rate = cwnd * 8.0 / rtt # in Gbps

        if sender in flow_stats.keys():
          flow_stats[sender]['times'].append(time)
          flow_stats[sender]['rates'].append(rate)
          flow_stats[sender]['cwnds'].append(cwnd)
          flow_stats[sender]['rtts'].append(rtt)
        else:
          flow_stats[sender] = {}
          flow_stats[sender]['times'] = [time]
          flow_stats[sender]['rates'] = [rate]
          flow_stats[sender]['cwnds'] = [cwnd]
          flow_stats[sender]['rtts'] = [rtt]

  return flow_stats

# %%
#@title
def get_cum_cwnd(flow_stats):
  last_cwnd_of_senders = {}
  for sender in flow_stats.keys():
    last_cwnd_of_senders[sender] = 0

  cum_cwnds = {
      'times': [0],
      'cwnds': [0]
  }

  log_entries = []
  for sender, sender_logs in flow_stats.items():
    for i in range(len(sender_logs['times'])):
      log_entries.append((sender_logs['times'][i], sender_logs['cwnds'][i], sender))
    log_entries.append((log_entries[-1][0],0,sender))

  log_entries = sorted(log_entries, key=lambda x: x[0])

  for entry in log_entries:
    sender = entry[2]
    cum_cwnd = cum_cwnds['cwnds'][-1] - last_cwnd_of_senders[sender] + entry[1]
    cum_cwnds['cwnds'].append(cum_cwnd)
    cum_cwnds['times'].append(entry[0])
    last_cwnd_of_senders[sender] = entry[1]

  return cum_cwnds

# %%
notes = ['', '_FF']

# %%
#@title
trace_path = '~/bolt_cc_ns3/outputs/bolt-fairness/0_DEFAULT'
stats = {}
for note in notes:
  if (note == ''):
    key = 'default'
  else:
    key = note[1:] # Ignore the _ in front
  stats[key] = read_flow_stats(trace_path + note + '.log')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 9
#       7 else:
#       8   key = note[1:] # Ignore the _ in front
# ----> 9 stats[key] = read_flow_stats(trace_path + note + '.log')
#
# Cell In[2], line 5, in read_flow_stats(flow_stats_filename)
#       2 def read_flow_stats(flow_stats_filename):
#       4   flow_stats = {}
# ----> 5   with open(flow_stats_filename, 'r') as f:
#       6     for line in f:
#       7       flow_stat_log = line.split()
#
# File ~/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'outputs/bolt-fairness/0_DEFAULT.log'

# %%
note_to_save_fig = 'default'

# %%
#@title
fontsize = 16
linestyle = (0,(4,4))
for note, data in stats.items():
  plt.figure(figsize=FIG_SIZE)

  for sender, flow_data in data.items():
    plt.plot(flow_data['times'],flow_data['rates'],
             label="Flow " + str(int(sender.split(':')[1])-PORT_NO_START+1))

  plt.legend(loc = 'upper center', frameon=False, fontsize=fontsize-2) # title = 'Flow ID', 
  plt.grid(linestyle =linestyle)
  print('Flow Rates of Bolt (' + note + ')')
  plt.xlabel('Time (msec)', fontsize=fontsize+2)
  plt.ylabel('Throughput (Gbps)', fontsize=fontsize+2)
  plt.xticks(fontsize=fontsize)
  plt.yticks(fontsize=fontsize)
  plt.ylim([0,110])
  plt.xlim([0,70])
  plt.gca().spines["right"].set_linestyle(linestyle)
  plt.gca().spines["right"].set_alpha(0.5)
  plt.gca().spines["right"].set_color('gray')
  plt.gca().spines["left"].set_linestyle(linestyle)
  plt.gca().spines["left"].set_alpha(0.5)
  plt.gca().spines["left"].set_color('gray')
  plt.gca().spines["top"].set_linestyle(linestyle)
  plt.gca().spines["top"].set_alpha(0.5)
  plt.gca().spines["top"].set_color('gray')
  plt.gca().spines["bottom"].set_linestyle(linestyle)
  plt.gca().spines["bottom"].set_alpha(0.5)
  plt.gca().spines["bottom"].set_color('gray')
  plt.tight_layout()
  if (note == note_to_save_fig and SAVE_FIG):
    plt.savefig('/usr/local/google/home/serhatarslan/Documents/Bolt-Figures/fairness.pdf')
  plt.show()
# Out:
# Flow Rates of Bolt (default)
# Flow Rates of Bolt (FF)

# %%
#@title
plt.figure(figsize=(4*len(notes),4))
xlim = None # [0,0.0005]
ax = []
idx = 0

for note, data in stats.items():
  idx += 1
  if (idx==1):
    ax.append(plt.subplot(1,len(notes),idx))
  else:
    ax.append(plt.subplot(1,len(notes),idx, sharey=ax[0]))

  for sender, flow_data in data.items():
    plt.plot(flow_data['times'],flow_data['rtts'],label=sender)

  if xlim is not None:
    plt.xlim(xlim)

  plt.legend()
  plt.grid()
  plt.title('RTT Measurements (' + note + ')')
  if (idx == 1):
    plt.ylabel('RTT (usec)')
  plt.xlabel('Time (sec)')
  plt.tight_layout()
  
plt.show()

# %%
note_to_analyze = None

# %%
#@title
if (note_to_analyze):
  output_notebook()
  p = figure(plot_width=900, plot_height=400)

  # print(plt.rcParams['axes.prop_cycle'].by_key()['color'])
  colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
  idx = 0
  for sender, flow_data in stats[note_to_analyze].items():
    p.line(flow_data['times'],flow_data['cwnds'], legend_label=sender, line_color=colors[idx])
    idx += 1
  show(p)

# %%
#@title
for note, data in stats.items():
  stats[note]['cum_cwnds'] = get_cum_cwnd(data)

# %%
notes_for_cum_cwnd = ['default','FF']

# %%
#@title
plt.figure(figsize=(10,6))
xlim_cum_cwnd = None # [0.00195, 0.00215]

for note, data in stats.items():
  if (note in notes_for_cum_cwnd):
    plt.plot(data['cum_cwnds']['times'], data['cum_cwnds']['cwnds'], label=note)
plt.axhline(y=100 , color='C2', linestyle='-', lw=3, label='BDP')

if xlim_cum_cwnd is not None:
  plt.xlim(xlim_cum_cwnd)
plt.ylim([50,130])

plt.title('Cumulative Cwnds of Algorithms During Congestion')
plt.xlabel('Time (msec)')
plt.ylabel('Cumulative Cwnd (KB)')
plt.grid()
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()
